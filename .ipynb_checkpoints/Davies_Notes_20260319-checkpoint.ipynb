# %%
# Create a clean environment
# Use the ! prefix to run shell commands in Jupyter notebook
#!conda create -n kasanka python=3.11 -y
#!conda activate kasanka

# Note: The conda activate command might not work as expected in Jupyter
# You may need to restart the kernel with the new environment, or use:
import sys
# !conda install -n kasanka ipykernel -y
# !python -m ipykernel install --user --name kasanka --display-name "Python (kasanka)"
# Then switch to the kasanka kernel from the Jupyter menu: Kernel > Change kernel

# %%
# Install JupyterLab and core packages
# Use the ! prefix to run shell commands in Jupyter
# !conda install -y numpy pandas matplotlib scipy scikit-learn rasterio
# !pip install opencv-python utm
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
# 'powershell' is not recognized as an internal or external command,
# operable program or batch file.
# ...

# %%
# Install PyTorch
# !pip install torch torchvision torchaudio

# %%
# Install Visual Studio Code (great Jupyter support),  
#Git (for version control), and common liibraries
# !pip install numpy pandas matplotlib seaborn

# %%
#Install jupyterlab GitHub Connector
# !pip install jupyterlab
# !pip install jupyterlab-git

# %%
#change the working directory for the entire notebook session
# %cd kasanka
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Import the os module first
import os

# Check your current working directory
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")
# Out:
# Current working directory: C:\Users\mallo\OneDrive - University of Arizona\Documents\GitHub\MalloryLouiseDavies\kasanka

# %%
import glob
import os

# Check your current working directory
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")
# Out:
# Current working directory: C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet

# %%
# Change the working directory to the appropriate path
# If using Stoner_lab One Drive files, UPDATE "C:\Users\mallo\" with local synced path
os.chdir(r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet")

# Check your current working directory
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")
# Out:
# Current working directory: C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet

# %%
from queue import Queue
import sys
from threading import Thread
import time

import cv2

class VideoReader:
    def __init__(self, video_file, queue_size=128):
        # initialize the file video stream along with the boolean
        # used to indicate if the thread should be stopped or not
        self.stream = cv2.VideoCapture(video_file)
        self.stopped = False
        # initialize the queue used to store frames read from
        # the video file
        self.Q = Queue(maxsize=queue_size)
        self.frame_num = 0
        self.false_count = 0 
        print('reading video from ', video_file)
        

    def start(self):
        # start a thread to read frames from the file video stream
        t = Thread(target=self.update, args=())
        t.daemon = True
        t.start()
        time.sleep(5)
        print('starting video reader...')
        return self

    def update(self):
        # keep looping infinitely
        # frame_num = 0
        print('update starting...')
        while True:
            # if frame_num == 100:
            #     break
            # if the thread indicator variable is set, stop the
            # thread
            if self.stopped:
                return

            # otherwise, ensure the queue has room in it
            if not self.Q.full():
                # read the next frame from the file

                (grabbed, frame) = self.stream.read()
                self.frame_num += 1
                
                
                # add the frame to the queue
                if not grabbed:
                    if self.false_count > 500:
                        print('no more frames')
                        self.stop()
                        return
                    else:
                        if self.frame_num % 25 == 0:
                            print('queue, {}, {}'.format(self.frame_num, grabbed))
                        self.false_count += 1
                else:
                    self.Q.put(frame)
                    self.false_count = 0
                

    def read(self):
        # return next frame in the queue
        return self.Q.get()


    def more(self):
        # return True if there are still frames in the queue
        return self.Q.qsize() > 0

    def stop(self):
        # indicate that the thread should be stopped
        self.stopped = True
        self.stream.release()
        print('stopped')
    
    def is_stopped(self):
        return self.stopped
    
    def is_full(self):
        return self.Q.full()
        
        
    def close(self):
        self.stop()

# %% [markdown]
# ### Get the paths to all the video files and check if any have already been processed

# %%
# import glob
# import os

# # parent folder containing folders to the videos
# # parent_video_folder = '.../kasanka-bats/gopros/' 
# parent_video_folder = f'bighatchet-bats\\cameras\\' 

# # parent folder where extracted data is stored
# # parent_output_folder = '.../kasanka-bats/processed/deep-learning'
# parent_output_folder = f'bighatchet-bats\\processed\\deep-learning'

# all_video_files = []
# #for date in ['16Nov', '17Nov', '18Nov', '19Nov', '20Nov']:
# for date in ['20Jul']:
#    all_video_files.extend(glob.glob(parent_video_folder + date + '/*/*.MP4'))
# all_video_files.sort()

# #List that will contain the paths to the videos that need darkness values
# video_files = []

# for video_file in all_video_files:
    
#    video_name = os.path.basename(video_file)
#    video_name = video_name.split('.')[-2]
#    observation_name = video_file.split('/')[-2]
#    output_folder = os.path.join(parent_output_folder, video_file.split('/')[-3], observation_name)
    
#    if os.path.exists(os.path.join(output_folder, f'mean-blue-{video_name}.npy')):
#         # Skip if darkness values already calculated for the video
#        continue
#    else:
#        video_files.append(video_file)

# %%
# import glob
# import os

# # parent folder containing folders to the videos
# # parent_video_folder = '.../kasanka-bats/gopros/' 
# parent_video_folder = f'bighatchet-bats\\cameras\\' 

# # parent folder where extracted data is stored
# # parent_output_folder = '.../kasanka-bats/processed/deep-learning'
# parent_output_folder = f'bighatchet-bats\\processed\\deep-learning'

# all_video_files = []
# #for date in ['16Nov', '17Nov', '18Nov', '19Nov', '20Nov']:
# for date in ['20Jul','14Jul']:
#    all_video_files.extend(glob.glob(parent_video_folder + date + '/*/*.MP4'))
# all_video_files.sort()

# #List that will contain the paths to the videos that need darkness values
# video_files = []

# for video_file in all_video_files:
    
#    video_name = os.path.basename(video_file)
#    video_name = video_name.split('.')[-2]
   
#    # Fix: Use os.path.normpath to handle path separators correctly
#    video_path_parts = os.path.normpath(video_file).split(os.sep)
   
#    # Get the observation name (second-to-last directory)
#    observation_name = video_path_parts[-2]
   
#    # Get the date directory (third-to-last directory)
#    date_dir = video_path_parts[-3]
   
#    output_folder = os.path.join(parent_output_folder, date_dir, observation_name)
    
#    if os.path.exists(os.path.join(output_folder, f'mean-blue-{video_name}.npy')):
#         # Skip if darkness values already calculated for the video
#        continue
#    else:
#        video_files.append(video_file)

# %%
## MLD EDITS 2026.03.24 ##

import glob
import os

# parent folder containing folders to the videos
# parent_video_folder = '.../kasanka-bats/gopros/' 
parent_video_folder = f'bighatchet-bats\\cameras\\' 

# parent folder where extracted data is stored
# parent_output_folder = '.../kasanka-bats/processed/deep-learning'
parent_output_folder = f'bighatchet-bats\\processed\\deep-learning'

# Initialize an empty list to store all video file paths
all_video_files = []
for date in ['14Jul', '20Jul']: # Loop through specific dates to find videos from each date
    # Fix path joining for Windows
    search_path = os.path.join(parent_video_folder, date, "**", "*.MP4")
    all_video_files.extend(glob.glob(search_path, recursive=True)) # Use recursive glob to find all MP4 files
all_video_files.sort() # Sort the file paths alphabetically

# List that will contain the paths to the videos that need darkness values
video_files = []


# Create a list of videos' darkness values
for video_file in all_video_files:
    
    video_name = os.path.basename(video_file) # Extract the base filename without extension
    video_name = os.path.splitext(video_name)[0]  # Properly split filename and extension
    
    # Fix path splitting for Windows
    path_parts = video_file.split(os.sep)
    observation_name = path_parts[-2]  # Extract observation folder name (parent directory of the video)
    date_folder = path_parts[-3]  # Extract date folder name
    
    output_folder = os.path.join(parent_output_folder, date_folder, observation_name)
    
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    
    if os.path.exists(os.path.join(output_folder, f'mean-blue-{video_name}.npy')):
        # Skip if darkness values already calculated for the video
        continue
    else:
        video_files.append(video_file)

# %% [markdown]
# ### Use multiprocessing to get the mean darkness in each frame in each video

# %%
# from multiprocessing import Pool
# import os
# import time

# import numpy as np

# process_every_n_frames = 1
    
# def get_darkness_info(video_file):
#     video_stream = None
#     try:
#         # parent_output_folder = '.../kasanka-bats/processed/deep-learning'
#         parent_output_folder = f'bighatchet-bats\\processed\\deep-learning'

#         observation_name = video_file.split('/')[-2]

#         output_folder = os.path.join(parent_output_folder, video_file.split('/')[-3], observation_name)
        
#         os.makedirs(output_folder, exist_ok=True)

#         video_name = os.path.basename(video_file)
#         video_name = video_name.split('.')[-2]

#         print('Processing', video_name)

#         frame_count = 0
#         video_stream = VideoReader(video_file).start()
#         time.sleep(1)
#         last_frame = None

#         mean_blue = []
#         median_blue = []
#         max_blue = []

#         started = False

#         while video_stream.more():

#             if video_stream.is_full() or video_stream.is_stopped():
#                 if not started:
#                     tic = time.time()
#                     started=True
#                 if frame_count % 4000 == 0:
#                     print(frame_count, 'frames processed')

#                 frame = video_stream.read()
#                 blue_frame = frame[..., 0] # 0 because BGR from opencv

#                 mean_blue.append(np.mean(blue_frame))
#                 median_blue.append(np.median(blue_frame))
#                 max_blue.append(blue_frame.max())

#                 frame_count += 1

#         video_stream.stop()

#         np.save(os.path.join(output_folder, f'mean-blue-{video_name}.npy'), np.array(mean_blue))

#         toc = time.time()
#         print(f'total_time {toc - tic}, fps: {frame_count / (toc-tic)}')
        
#     except:
#         if video_stream:
#             video_stream.stop()
#             print(f'FAILED: {video_file}')
    

# # If multiprocessing isn't working, this can be switched to a for loop
# # if __name__ == '__main__':
# #     with Pool(processes=4) as pool:
# #         pool.map(get_darkness_info, video_files)
        
# # i.e.
# # for video_file in video_files:
# #    get_darkness_info(video_files)

# %%
from multiprocessing import Pool
import os
import time
import numpy as np
import cv2  # Using OpenCV 

process_every_n_frames = 1
    
def get_darkness_info(video_file):
    video_stream = None
    try:
        # Update with your Windows path
        parent_output_folder = f'bighatchet-bats\\processed\\deep-learning'

        # Fix path splitting for Windows
        path_parts = video_file.split(os.sep)
        observation_name = path_parts[-2]
        date_folder = path_parts[-3]

        output_folder = os.path.join(parent_output_folder, date_folder, observation_name)
        
        os.makedirs(output_folder, exist_ok=True)

        video_name = os.path.basename(video_file)
        video_name = os.path.splitext(video_name)[0]  # Properly split filename and extension

        print('Processing', video_name)

        # Open video with OpenCV
        video_stream = cv2.VideoCapture(video_file)
        if not video_stream.isOpened():
            raise Exception(f"Could not open video file: {video_file}")

        frame_count = 0
        mean_blue = []
        median_blue = []
        max_blue = []

        tic = time.time()

        # Process frames with OpenCV
        while True:
            ret, frame = video_stream.read()
            if not ret:
                break  # End of video
                
            if frame_count % process_every_n_frames == 0:
                blue_frame = frame[..., 0]  # 0 because BGR from OpenCV
                
                mean_blue.append(np.mean(blue_frame))
                median_blue.append(np.median(blue_frame))
                max_blue.append(blue_frame.max())
                
            frame_count += 1
            
            if frame_count % 4000 == 0:
                print(frame_count, 'frames processed')

        # Release video resource
        video_stream.release()

        np.save(os.path.join(output_folder, f'mean-blue-{video_name}.npy'), np.array(mean_blue))

        toc = time.time()
        print(f'total_time {toc - tic}, fps: {frame_count / (toc-tic)}')
        
    except Exception as e:
        if video_stream:
            video_stream.release()  # Release OpenCV video resource
        print(f'FAILED: {video_file}')
        print(f'Error: {str(e)}')
    

# If multiprocessing isn't working, this can be switched to a for loop
# if __name__ == '__main__':
#     with Pool(processes=4) as pool:
#         pool.map(get_darkness_info, video_files)
        
# i.e.
for video_file in video_files:
   get_darkness_info(video_file)
# Out:
# Processing 14Jul_thermal
# 4000 frames processed
# 8000 frames processed
# 12000 frames processed
# 16000 frames processed
# total_time 219.01280546188354, fps: 83.61611532886897

# %% [markdown]
# ### Combine generated darkness files so that each camera has a darkness file instead of each video clip

# %%
# day_folders = sorted(glob.glob(os.path.join(parent_output_folder, '*')))
# for day_folder in day_folders[:]:
#     camera_folders = sorted(glob.glob(os.path.join(day_folder, '*')))
#     for camera_folder in camera_folders[:]:
#         if os.path.exists(os.path.join(camera_folder, 'blue-means.npy')):
#             print('already seen', camera_folder, day_folder)
#             continue
#         mean_files = sorted(glob.glob(os.path.join(camera_folder, 'mean-*.npy')))
#         means = []
#         for f in mean_files:
#             m = np.load(f)
#             means.append(m)
#         means = np.hstack(means)
#         np.save(os.path.join(camera_folder, 'blue-means.npy'), means)
#         for f in mean_files:
#             os.remove(f)
# Out:
# already seen bighatchet-bats\processed\deep-learning\14Jul\thermal bighatchet-bats\processed\deep-learning\14Jul
# already seen bighatchet-bats\processed\deep-learning\20Jul\example bighatchet-bats\processed\deep-learning\20Jul
# already seen bighatchet-bats\processed\deep-learning\20Jul\thermal bighatchet-bats\processed\deep-learning\20Jul

# %%
day_folders = sorted(glob.glob(os.path.join(parent_output_folder, '*')))
for day_folder in day_folders[:]:
    camera_folders = sorted(glob.glob(os.path.join(day_folder, '*')))
    for camera_folder in camera_folders[:]:
        if os.path.exists(os.path.join(camera_folder, 'blue-means.npy')):
            print('already seen', camera_folder, day_folder)
            continue
        mean_files = sorted(glob.glob(os.path.join(camera_folder, 'mean-*.npy')))
        means = []
        for f in mean_files:
            m = np.load(f)
            means.append(m)
        
        # Check if means list is not empty before using np.hstack
        if means:  # This checks if the list is not empty
            means = np.hstack(means)
            np.save(os.path.join(camera_folder, 'blue-means.npy'), means)
            # Only remove files if we successfully processed them
            for f in mean_files:
                os.remove(f)
        else:
            print(f"No mean files found in {camera_folder}")
# Out:
# already seen bighatchet-bats\processed\deep-learning\20Jul\example bighatchet-bats\processed\deep-learning\20Jul
# already seen bighatchet-bats\processed\deep-learning\20Jul\thermal bighatchet-bats\processed\deep-learning\20Jul

# %% [markdown]
# This notebook takes the raw tracks for each observation and finds all crossing tracks and extracts all nessisary assosiated information for population estimates including things like bat size, frame darkness etc. All this information is saved in one dictionary for each observation which can be used in other notebooks for further processing.

# %%
import glob
import os
import matplotlib.pyplot as plt

import numpy as np

from bat_functions import threshold_short_tracks
from bat_functions import measure_crossing_bats
#Warning, the utm package is not installed and so won't be imported. You will not be able to use the function latlong_dict_to_utm.

# %%
# Get the height of the video frames

# This can either be manually set or derived from a loaded image frame

# DERIVED (uncomment two lines below to get height by loading an image file)
# image_file = '.../kasanka-bats/processed/deep-learning/19Nov/BBC/example-frames/19Nov_BBC_obs-ind_40500.jpg'
#  frame_height = plt.imread(image_file).shape[0]
image_file = r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\20Jul\thermal\example-frames\20Jul_thermal_obs-ind_000001.jpg"
frame_height = plt.imread(image_file).shape[0]

# MANUALLY SET (Warning! This value must match the actual frame height in the videos being processed!)
# frame_height = 1520
print(frame_height)
# Out:
# 720

# %%
# Used for saving the processed track files
#root_folder = "" #".../kasanka-bats/processed/deep-learning"
root_folder = r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning"

# %% [markdown]
# ## Take all tracks found and filter out all that don't cross the count line
# Save these crossing tracks seprately so this only has to be run once

# %%
# def get_all_raw_tracks(day_folders, verbose=True):
#     """ Get all raw track files within the list of folders.
    
#     This should only be used if using the same file structure that we assume:
    
#     - day_folder_1
#           camera1
#               raw_tracks.npy
#           camera2
#               raw_tracks.npy
#           cameraN
#               raw_tracks.npy
#     - day_folder_2
#           camera1
#               raw_tracks.npy
#     ...
    
#     Args:
#         day_folder: list of paths to folders that contain sub folders for each 
#             camera. Those subfolders contain raw_tracks.npy files
            
#     Return list of full paths to raw_track.npy files
        
#     """
    
#     all_track_files = []
#     for day_folder in day_folders:
#         print(day_folder)
#         date = os.path.basename(day_folder) 
#         track_files = sorted(
#             glob.glob(os.path.join(day_folder, '*/raw_tracks.npy'))
#         )
#         all_track_files.extend(track_files)
#     return all_track_files

# def save_crossing_tracks_from_raw_tracks(file, out_file, verbose=True):
#     """ Save all crossing tracks after preproccesing all tracks in observation.
    
#     Args:
#         file: full path to a numpy file that is a list of track objects
#         out_file: full path where list of crossing tracks should be saved
    
#     Nothing is returned
#     """
    
#     raw_track_list = np.load(file, allow_pickle=True)
#     if verbose:
#         print(f"{len(raw_track_list)} raw tracks in observation.")
#     # Get rid of tracks less than two points long
#     tracks_list = threshold_short_tracks(raw_track_list, min_length_threshold=2)
#     # Get list of tracks that cross the mid line
#     crossing_tracks_list = measure_crossing_bats(tracks_list, 
#                                                  frame_height=frame_height)
#     if verbose:
#         print(f"{len(crossing_tracks_list)} tracks crossing counting line",
#               "in observation.")

#     np.save(out_file, np.array(crossing_tracks_list, dtype=object))

# %%
import os
import glob
import numpy as np

def get_all_raw_tracks(day_folders, verbose=True):
    """ Get all raw track files within the list of folders.
    
    This should only be used if using the same file structure that we assume:
    
    - day_folder_1
          camera1
              raw_tracks.npy
          camera2
              raw_tracks.npy
          cameraN
              raw_tracks.npy
    - day_folder_2
          camera1
              raw_tracks.npy
    ...
    
    Args:
        day_folder: list of paths to folders that contain sub folders for each 
            camera. Those subfolders contain raw_tracks.npy files
            
    Return list of full paths to raw_track.npy files
        
    """
    
    all_track_files = []
    for day_folder in day_folders:
        if verbose:
            print(day_folder)
        date = os.path.basename(os.path.normpath(day_folder))
        # Use os.path.join for path construction and normpath to handle any path format issues
        search_pattern = os.path.join(day_folder, "*", "raw_tracks.npy")
        track_files = sorted(glob.glob(search_pattern))
        all_track_files.extend(track_files)
    return all_track_files

def threshold_short_tracks(track_list, min_length_threshold=2):
    """Filter out tracks shorter than the threshold."""
    return [track for track in track_list if len(track) >= min_length_threshold]

def measure_crossing_bats(tracks_list, frame_height):
    """Get list of tracks that cross the mid line."""
    # Assuming this function is defined elsewhere
    # Placeholder implementation
    crossing_tracks = []
    mid_line = frame_height / 2
    
    # Implementation would go here
    
    return crossing_tracks

def save_crossing_tracks_from_raw_tracks(file, out_file, verbose=True, frame_height=720):
    """ Save all crossing tracks after preproccesing all tracks in observation.
    
    Args:
        file: full path to a numpy file that is a list of track objects
        out_file: full path where list of crossing tracks should be saved
        verbose: whether to print progress information
        frame_height: height of the frame for determining crossing line
    
    Nothing is returned
    """
    
    raw_track_list = np.load(file, allow_pickle=True)
    if verbose:
        print(f"{len(raw_track_list)} raw tracks in observation.")
    # Get rid of tracks less than two points long
    tracks_list = threshold_short_tracks(raw_track_list, min_length_threshold=2)
    # Get list of tracks that cross the mid line
    crossing_tracks_list = measure_crossing_bats(tracks_list, frame_height=frame_height)
    if verbose:
        print(f"{len(crossing_tracks_list)} tracks crossing counting line",
              "in observation.")

    # Ensure the directory exists before saving
    os.makedirs(os.path.dirname(os.path.abspath(out_file)), exist_ok=True)
    np.save(out_file, np.array(crossing_tracks_list, dtype=object))

# %%
# Don't worry if you get the following warning:
# RuntimeWarning: All-NaN slice encountered
#  max_edge = np.nanmax(track['rects'], 1)


# If you use our file structure you can use some of the commented lines below 
# Otherwise just do whatever fits your needs to end up with a list of the raw_track.npy
# files that you want to process as we do in the uncommented part
# Get path to the folders for each observation date
# (Each of these contains folders for each camera which contain 'raw_tracks.npy' etc)
# UNCOMMENT THESE LINES OF CODE TO GET MANY RAW TRACK FILES IF USING OUR FILE SYSTEM
# day_folders = day_folders = sorted(
#     glob.glob('.../kasanka-bats/processed/deep-learning/*Nov')
# )
# raw_track_files = get_all_raw_track_files(day_folders)      

day_folders = sorted(
    glob.glob(r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\*Jul")
)
raw_track_files = get_all_raw_track_files(day_folders)   


# This is an examples of just manually setting the paths to the raw tracks
#raw_track_files = [
#    ".../wetransfer_raw_tracks_2023-02-07_1331/raw_tracks_2-Dec-2020_MusolaTower/raw_tracks_2-Dec-2020_MusolaTower.npy",
#    ".../wetransfer_raw_tracks_2023-02-07_1331/raw_tracks_26-Nov-2021_MusolaTower/raw_tracks_26-Nov-2021_MusolaTower.npy"
#]
# raw_track_files = [
#   r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\20Jul\thermal\raw_tracks.npy"
# ]

verbose = True

for track_file in raw_track_files:
    camera_folder = os.path.dirname(track_file)
    # New file path for the crossing tracks that will be saved
    crossing_track_file = os.path.join(camera_folder, 'crossing_tracks.npy')
    if os.path.exists(crossing_track_file):
        # If the crossing tracks from this camera have already been saved don't
        # re-find them
        continue
    save_crossing_tracks_from_raw_tracks(track_file, crossing_track_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 20
#       1 # Don't worry if you get the following warning:
#       2 # RuntimeWarning: All-NaN slice encountered
#       3 #  max_edge = np.nanmax(track['rects'], 1)
#    (...)     14 # )
#      15 # raw_track_files = get_all_raw_track_files(day_folders)
#      17 day_folders = sorted(
#      18     glob.glob(r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\*Jul")
#      19 )
# ---> 20 raw_track_files = get_all_raw_track_files(day_folders)
#      23 # This is an examples of just manually setting the paths to the raw tracks
#      24 #raw_track_files = [
#      25 #    ".../wetransfer_raw_tracks_2023-02-07_1331/raw_tracks_2-Dec-2020_MusolaTower/raw_tracks_2-Dec-2020_MusolaTower.npy",
#    (...)     29 #   r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\20Jul\thermal\raw_tracks.npy"
#      30 # ]
#      32 verbose = True
#
# NameError: name 'get_all_raw_track_files' is not defined

# %%
# import os
# import glob
# import numpy as np

# # Define the missing function to get all raw track files
# def get_all_raw_track_files(day_folders):
#     """
#     Function to get all raw track files from a list of day folders
#     """
#     raw_track_files = []
#     for day_folder in day_folders:
#         # Assuming raw_tracks.npy is in a subdirectory like thermal/
#         track_files = glob.glob(os.path.join(day_folder, '*', 'raw_tracks.npy'))
#         raw_track_files.extend(track_files)
#     return raw_track_files

# # Define the function to save crossing tracks
# def save_crossing_tracks_from_raw_tracks(track_file, crossing_track_file):
#     """
#     Function to process raw tracks and save crossing tracks
#     """
#     # Load the raw tracks
#     tracks = np.load(track_file, allow_pickle=True)
    
#     # Process each track (this is a placeholder - implement your actual logic)
#     crossing_tracks = []
#     for track in tracks:
#         # Example processing - you'll need to replace with your actual logic
#         if 'rects' in track:
#             try:
#                 max_edge = np.nanmax(track['rects'], 1)
#                 # Add your criteria for crossing tracks here
#                 crossing_tracks.append(track)
#             except ValueError:
#                 # Handle the "All-NaN slice encountered" warning
#                 pass
    
#     # Save the crossing tracks
#     np.save(crossing_track_file, np.array(crossing_tracks, dtype=object))
    
#     if verbose:
#         print(f"Saved {len(crossing_tracks)} crossing tracks to {crossing_track_file}")

# # Your existing code starts here
# day_folders = sorted(
#     glob.glob(r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\*Jul")
# )
# raw_track_files = get_all_raw_track_files(day_folders)   

# verbose = True

# for track_file in raw_track_files:
#     camera_folder = os.path.dirname(track_file)
#     # New file path for the crossing tracks that will be saved
#     crossing_track_file = os.path.join(camera_folder, 'crossing_tracks.npy')
#     if os.path.exists(crossing_track_file):
#         # If the crossing tracks from this camera have already been saved don't
#         # re-find them
#         continue
#     save_crossing_tracks_from_raw_tracks(track_file, crossing_track_file)

# %% [markdown]
# ### Visualize some of the crossing tracks (Bonus)
# ### Required processing continues at the next bolded title

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#c_tracks_file = ".../wetransfer_raw_tracks_2023-02-07_1331/raw_tracks_26-Nov-2021_MusolaTower/crossing_tracks.npy"
c_tracks_file = r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\20Jul\thermal\crossing_tracks.npy"
tracks = np.load(c_tracks_file, allow_pickle=True)

# %%
num_tracks = 100

for track_ind in np.linspace(0, len(tracks), num_tracks, endpoint=False, dtype=int):

    track = tracks[track_ind]
    plt.scatter(track['track'][:, 0], track['track'][:, 1], s=1)
    plt.gca().set_aspect('equal')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 5
#       1 num_tracks = 100
#       3 for track_ind in np.linspace(0, len(tracks), num_tracks, endpoint=False, dtype=int):
# ----> 5     track = tracks[track_ind]
#       6     plt.scatter(track['track'][:, 0], track['track'][:, 1], s=1)
#       7     plt.gca().set_aspect('equal')
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# First, make sure tracks is not empty
if len(tracks) > 0:
    # Adjust num_tracks if it's larger than the available tracks
    num_tracks = min(100, len(tracks))
    
    # Generate indices for the tracks we want to plot
    track_indices = np.linspace(0, len(tracks)-1, num_tracks, endpoint=False, dtype=int)
    
    for track_ind in track_indices:
        track = tracks[track_ind]
        
        # Check if the track has data before plotting
        if 'track' in track and len(track['track']) > 0:
            plt.scatter(track['track'][:, 0], track['track'][:, 1], s=1)
            plt.gca().set_aspect('equal')
        else:
            print(f"Track at index {track_ind} has no data, skipping.")
else:
    print("The tracks array is empty.")
# Out:
# The tracks array is empty.

# %% [markdown]
# ### For each camera observation on each day, complile all nessisary information about each crossing bat needed to estimate the total population
#
# This expects the file structure to be the same as we use, i.e.
#
# * project_folder
#   * date1
#     * camera1
#       * crossing_tracks.npy
#       * blue-means.npy
#       * ...
#     * camera2
#       * crossing_tracks.npy
#       * blue-means.npy
#       * ...
#     * ...
#   * date2
#     * camera1
#       * crossing_tracks.npy
#       * blue-means.npy
#       * ...
#     * ...
#   * ...

# %%
# # day_folders = sorted(
# #     glob.glob('.../kasanka-bats/processed/deep-learning/*Nov')
# # )
# day_folders = sorted(
#     glob.glob(r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\*Jul")
# )

# observations = {}
# for day_folder in day_folders:
#     print(day_folder)

#     date = os.path.basename(day_folder)
#     track_files = sorted(glob.glob(os.path.join(day_folder, '*/crossing_tracks.npy')))
#     observations[date] = {}
    
#     for track_file in track_files: 
#         camera = track_file.split('/')[-2]
#         obs = {'date': date,
#                'camera': camera,
#                }
#         crossing_tracks_list = np.load(track_file, allow_pickle=True)
#         # Load the frame darkness values as calculated in get-observation-frame-darkness.ipynb
#         darkness_means = np.load(os.path.join(day_folder, camera, 'blue-means.npy'))
#         passing_bat_frame = []
#         passing_bat_size = []
#         passing_bat_track_ind = []
#         passing_bat_direction = []
#         passing_bat_track_id = []
#         passing_bat_darkness = []
#         passing_track_length = []
#         for track_ind, track in enumerate(crossing_tracks_list):
#             if track['crossed'] > 0:
#                 passing_bat_frame.append(track['crossed'])
#                 passing_bat_size.append(track['mean_wing'])
#                 passing_bat_track_id.append(track_ind)
#                 passing_bat_direction.append(1)
#                 passing_bat_darkness.append(darkness_means[track['crossed']])
#                 passing_track_length.append(len(track['track']))

#             elif track['crossed'] < 0:
#                 passing_bat_frame.append(track['crossed'])
#                 passing_bat_size.append(track['mean_wing'])
#                 passing_bat_track_id.append(track_ind)
#                 passing_bat_direction.append(-1)
#                 passing_bat_darkness.append(darkness_means[-track['crossed']])
#                 passing_track_length.append(len(track['track']))

#         obs['frames'] = np.array(passing_bat_frame)
#         obs['mean_wing'] = np.array(passing_bat_size)
#         obs['ids'] = np.array(passing_bat_track_id)
#         obs['direction'] = np.array(passing_bat_direction)
#         obs['darkness'] = np.array(passing_bat_darkness)
#         obs['track_length'] = np.array(passing_track_length)
#         observations[date][camera] = obs
        
# # Save the track crossing information for each observation (camera, date)
# observation_root = os.path.join(root_folder, 'observations')
# for date, day_obs in observations.items():
#     day_folder = os.path.join(observation_root, date)
#     os.makedirs(day_folder, exist_ok=True)
#     for cam_ind, (cam_name, obs) in enumerate(day_obs.items()):
#         obs_name = f'{date}-observation-{cam_name}.npy'
#         obs_file = os.path.join(day_folder, obs_name)
#         np.save(obs_file, obs)

# %%
import os
import glob
import numpy as np

day_folders = sorted(
    glob.glob(r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\*Jul")
)

observations = {}
for day_folder in day_folders:
    print(day_folder)

    date = os.path.basename(day_folder)
    track_files = sorted(glob.glob(os.path.join(day_folder, '*/crossing_tracks.npy')))
    observations[date] = {}
    
    for track_file in track_files: 
        # Fix: Use os.path.dirname and os.path.basename to properly extract camera name
        camera = os.path.basename(os.path.dirname(track_file))
        obs = {'date': date,
               'camera': camera,
               }
        crossing_tracks_list = np.load(track_file, allow_pickle=True)
        
        # Fix: Construct the path to blue-means.npy properly
        darkness_means_path = os.path.join(os.path.dirname(track_file), 'blue-means.npy')
        darkness_means = np.load(darkness_means_path)
        
        passing_bat_frame = []
        passing_bat_size = []
        passing_bat_track_ind = []
        passing_bat_direction = []
        passing_bat_track_id = []
        passing_bat_darkness = []
        passing_track_length = []
        
        for track_ind, track in enumerate(crossing_tracks_list):
            # Add bounds checking
            if track['crossed'] > 0 and track['crossed'] < len(darkness_means):
                passing_bat_frame.append(track['crossed'])
                passing_bat_size.append(track['mean_wing'])
                passing_bat_track_id.append(track_ind)
                passing_bat_direction.append(1)
                passing_bat_darkness.append(darkness_means[track['crossed']])
                passing_track_length.append(len(track['track']))

            elif track['crossed'] < 0 and -track['crossed'] < len(darkness_means):
                passing_bat_frame.append(track['crossed'])
                passing_bat_size.append(track['mean_wing'])
                passing_bat_track_id.append(track_ind)
                passing_bat_direction.append(-1)
                passing_bat_darkness.append(darkness_means[-track['crossed']])
                passing_track_length.append(len(track['track']))

        obs['frames'] = np.array(passing_bat_frame)
        obs['mean_wing'] = np.array(passing_bat_size)
        obs['ids'] = np.array(passing_bat_track_id)
        obs['direction'] = np.array(passing_bat_direction)
        obs['darkness'] = np.array(passing_bat_darkness)
        obs['track_length'] = np.array(passing_track_length)
        observations[date][camera] = obs
        
# Save the track crossing information for each observation (camera, date)
observation_root = os.path.join(r"C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed", 'observations')
for date, day_obs in observations.items():
    day_folder = os.path.join(observation_root, date)
    os.makedirs(day_folder, exist_ok=True)
    for cam_ind, (cam_name, obs) in enumerate(day_obs.items()):
        obs_name = f'{date}-observation-{cam_name}.npy'
        obs_file = os.path.join(day_folder, obs_name)
        np.save(obs_file, obs)
# Out:
# C:\Users\mallo\OneDrive - University of Arizona\Stoner_lab - Documents\Stoner Lab Home\Projects\Automated Count Project\bighatchet\bighatchet-bats\processed\deep-learning\20Jul
